# %% [markdown]
# # Demo Project
#
# Requirement | Answer
# ------------|---------
# A dataset | higher education entrance qualification quotes in Switzerland, see `maturitaetsquoten.tsv`
# A Jupyter notebook of your work | You're looking at it
# At least two graphics from pandas/matplotlib | See below
# A paragraph or two about the work you've done (data sourcing, data cleaning, etc) | Data is from <https://www.bfs.admin.ch/bfs/de/home/statistiken/bildung-wissenschaft/bildungsindikatoren/bildungssystem-schweiz/themen/abschluesse/maturitaetsquote.assetdetail.4282891.html> and cleaned up by hand from the "formatted" spreadsheat provided by BFS
# A paragraph or two about your findings | The quota has generally risen since it has been first tracked, but there are some cantons where the quota has dropped in the last ten years.
# A list of additional "nice to have" improvements - this can be other graphics, improvements on your existing graphics, or further data analysis. | see on bottom of notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_table('code/01-university-eligibility/maturitaetsquoten.tsv')

# %%
df.set_index(['Kanton', 'Geschlecht'], inplace=True)

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>1980</th>
#       <th>1981</th>
#       <th>1982</th>
#       <th>1983</th>
#       <th>1984</th>
#       <th>1985</th>
#       <th>1986</th>
#       <th>1987</th>
#       <th>1988</th>
#       <th>1989</th>
#       <th>...</th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#       <th>2010</th>
#       <th>2011</th>
#       <th>2012</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#     </tr>
#     <tr>
#       <th>Kanton</th>
#       <th>Geschlecht</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
df['10_years_difference'] = df['2016'] - df['2006']

# %%
ten_years = df.groupby('Kanton').mean().sort_values(
  '10_years_difference').transpose().loc[['2006','2016', 
                                                         '10_years_difference']]

# %% [markdown]
# ## Comparison of the biggest loosers and winners

# %%
ten_years.loc[['2006', '2016'],['OW', 'SH', 'UR', 'AG', 'BL']].plot()

# %% [markdown]
# ## Men vs Women today

# %%
df.loc[:,['2016']].plot(kind='barh', figsize=(4,10))
# would be nice to have this sorted, but ... I guess this is not working with
#  MultiIndices? Must do more research

# %%
# more noodling around with the code
df.stack().reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Kanton</th>
#       <th>Geschlecht</th>
#       <th>level_2</th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ZH</td>
#       <td>Frauen</td>
#       <td>1980</td>
#       <td>11.3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ZH</td>
#       <td>Frauen</td>
#       <td>1981</td>
#       <td>11.4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ZH</td>
#       <td>Frauen</td>
#       <td>1982</td>
#       <td>11.4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ZH</td>
#       <td>Frauen</td>
#       <td>1983</td>
# ...

# %%
# Per suggestion of Patrice: calculate difference between men and women
# Slicing as per http://stackoverflow.com/questions/14964493/multiindex-based-indexing-in-pandas
All = slice(None)
df.loc[(All,'Männer'),['2016']] - df.loc[(All, 'Frauen'),['2016']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>2016</th>
#     </tr>
#     <tr>
#       <th>Kanton</th>
#       <th>Geschlecht</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">AG</th>
#       <th>Frauen</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Männer</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">AI</th>
#       <th>Frauen</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Männer</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">AR</th>
#       <th>Frauen</th>
# ...

# %%
# That doesn't seem to work? But why?

df.loc[(All, 'Männer'), ['2016']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>2016</th>
#     </tr>
#     <tr>
#       <th>Kanton</th>
#       <th>Geschlecht</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ZH</th>
#       <th>Männer</th>
#       <td>32.3</td>
#     </tr>
#     <tr>
#       <th>BE</th>
#       <th>Männer</th>
#       <td>31.4</td>
#     </tr>
#     <tr>
#       <th>LU</th>
#       <th>Männer</th>
#       <td>27.6</td>
#     </tr>
#     <tr>
#       <th>UR</th>
#       <th>Männer</th>
#       <td>23.5</td>
#     </tr>
#     <tr>
#       <th>SZ</th>
#       <th>Männer</th>
#       <td>24.8</td>
#     </tr>
#     <tr>
# ...

# %%
# vs ...

df.xs('Männer', level=1)['2016']
# Out:
# Kanton
# ZH    32.3
# BE    31.4
# LU    27.6
# UR    23.5
# SZ    24.8
# OW    21.2
# NW    30.6
# GL    23.9
# ZG    36.7
# FR    39.6
# SO    28.4
# BS    41.9
# BL    41.2
# SH    35.0
# AR    30.4
# AI    25.6
# SG    28.4
# GR    32.7
# AG    31.9
# TG    25.7
# TI    42.8
# VD    32.7
# VS    33.5
# NE    39.2
# GE    39.4
# JU    31.8
# Name: 2016, dtype: float64

# %%
# Oh, so `loc[]` gives me another dataframe, while xs() will give me a series
#  which I can actually use to do arithmetic with.

# %%
# alternative version using cross section
df.xs('Männer', level=1)['2016'] - df.xs('Frauen', level=1)['2016']

# this gives me actual values, which is nice
# Out:
# Kanton
# ZH    -9.6
# BE   -10.6
# LU   -10.3
# UR    -9.9
# SZ   -11.6
# OW    -4.2
# NW    -6.5
# GL   -11.5
# ZG   -10.0
# FR   -16.2
# SO    -6.1
# BS    -6.1
# BL    -7.8
# SH    -5.4
# AR   -14.8
# AI   -13.7
# SG    -7.2
# GR    -7.3
# AG    -7.8
# TG   -11.4
# TI   -13.7
# VD   -10.7
# VS   -13.9
# NE   -15.1
# GE   -11.9
# JU   -21.8
# Name: 2016, dtype: float64

# %%
delta_df = pd.DataFrame(
  df.xs('Männer', level=1)['2016'] - df.xs('Frauen', level=1)['2016'], 
  columns=['2016'])
delta_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2016</th>
#     </tr>
#     <tr>
#       <th>Kanton</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ZH</th>
#       <td>-9.6</td>
#     </tr>
#     <tr>
#       <th>BE</th>
#       <td>-10.6</td>
#     </tr>
#     <tr>
#       <th>LU</th>
#       <td>-10.3</td>
#     </tr>
#     <tr>
#       <th>UR</th>
#       <td>-9.9</td>
#     </tr>
#     <tr>
#       <th>SZ</th>
#       <td>-11.6</td>
#     </tr>
#     <tr>
#       <th>OW</th>
#       <td>-4.2</td>
#     </tr>
#     <tr>
#       <th>NW</th>
#       <td>-6.5</td>
#     </tr>
#     <tr>
#       <th>GL</th>
# ...

# %%
delta_df['1980'] = df.xs('Männer', level=1)['1980'] - df.xs('Frauen', level=1)[
  '1980']

# %%
delta_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2016</th>
#       <th>1980</th>
#     </tr>
#     <tr>
#       <th>Kanton</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ZH</th>
#       <td>-9.6</td>
#       <td>2.3</td>
#     </tr>
#     <tr>
#       <th>BE</th>
#       <td>-10.6</td>
#       <td>4.1</td>
#     </tr>
#     <tr>
#       <th>LU</th>
#       <td>-10.3</td>
#       <td>4.1</td>
#     </tr>
#     <tr>
#       <th>UR</th>
#       <td>-9.9</td>
#       <td>5.8</td>
#     </tr>
#     <tr>
#       <th>SZ</th>
#       <td>-11.6</td>
#       <td>1.7</td>
#     </tr>
#     <tr>
#       <th>OW</th>
# ...

# %%
plt.switch_backend('pdf')
plt.style.use('stylelib/matplotlibrc')

delta_df.sort_values('2016').plot(kind='barh', figsize=(4,10))

# %%
# actually, create another plot, one with lines, that we can then continue to
#  work with in Illustrator
plt.style.use('stylelib/matplotlibrc')
ax = delta_df.transpose().sort_index().plot()
plt.savefig('code/01-university-eligibility/change.pdf')
plt.savefig('code/01-university-eligibility/change.svg')

# %%
delta_df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2016</th>
#       <th>1980</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>26.000000</td>
#       <td>26.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>-10.580769</td>
#       <td>3.350000</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>3.971500</td>
#       <td>3.116825</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>-21.800000</td>
#       <td>-5.200000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>-13.250000</td>
#       <td>2.075000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
# ...

# %% [markdown]
# So, what does this show us? While in 1980, the difference between genders was lower, but tended towards more men getting the qualification.
#
# Today, it is way more women that are getting qualified for higher education, with a maximum difference of almost 22 percent points in one case.
#
# So the questions here would be:
#
# - does this carry over to higher education?
# - does this carry over to higher education diplomas?
# - does this carry over to people in the workforce with higher education diplomas?
#
# Because that's potentially a whole lot of women that are highly educated and then quietly drop out of the workfore because of general mysogyny, glass ceilings and work models that hamper women with children …

# %% [markdown]
# ## To Do
#
# - [ ] Barchart sorted by women
# - [ ] Barchart grouped by canton
# - [ ] Trends (is it really going down in some cantons?)
# - [ ] Change between start of the records and now
# - [ ] How is the ratio connected to the how many people live in cities vs. rural areas?
# - [ ] How is the ratio connected to how many schools are available and close by?
